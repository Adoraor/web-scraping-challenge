# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
Soup = soup(html, 'html.parser')

# %%
# Extract all rows of data
rows = Soup.find_all('tr', class_='data-row')

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
from pprint import pprint

# Create an empty list

mars_data = []

# Loop through the scraped data to create a list of rows
for row in rows:
    tds = row.find_all('td')
    
    row_data = {
        'id': tds[0].text.strip(),
        'terrestrial_date': tds[1].text.strip(),
        'sol': tds[2].text.strip(),
        'ls': tds[3].text.strip(),
        'month': tds[4].text.strip(),
        'min_temp': tds[5].text.strip(),
        'pressure': tds[6].text.strip()
    }
        
    mars_data.append(row_data)
    
pprint(mars_data)
# Out:
# [{'id': '2',
#   'ls': '155',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '739.0',
#   'sol': '10',
#   'terrestrial_date': '2012-08-16'},
#  {'id': '13',
#   'ls': '156',
#   'min_temp': '-76.0',
#   'month': '6',
#   'pressure': '740.0',
#   'sol': '11',
#   'terrestrial_date': '2012-08-17'},
#  {'id': '24',
#   'ls': '156',
#   'min_temp': '-76.0',
#   'month': '6',
#   'pressure': '741.0',
#   'sol': '12',
#   'terrestrial_date': '2012-08-18'},
#  {'id': '35',
#   'ls': '157',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '732.0',
#   'sol': '13',
#   'terrestrial_date': '2012-08-19'},
#  {'id': '46',
#   'ls': '157',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '740.0',
#   'sol': '14',
#   'terrestrial_date': '2012-08-20'},
#  {'id': '57',
#   'ls': '158',
#   'min_temp': '-78.0',
#   'month': '6',
#   'pressure': '740.0',
#   'sol': '15',
#   'terrestrial_date': '2012-08-21'},
#  {'id': '68',
#   'ls': '158',
#   'min_temp': '-77.0',
#   'month': '6',
#   'pressure': '740.0',
#   'sol': '16',
#   'terrestrial_date': '2012-08-22'},
#  {'id': '79',
#   'ls': '159',
#   'min_temp': '-76.0',
#   'month': '6',
#   'pressure': '742.0',
#   'sol': '17',
#   'terrestrial_date': '2012-08-23'},
#  {'id': '112',
#   'ls': '161',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '741.0',
#   'sol': '21',
#   'terrestrial_date': '2012-08-27'},
#  {'id': '114',
#   'ls': '162',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '742.0',
#   'sol': '22',
#   'terrestrial_date': '2012-08-28'},
#  {'id': '123',
#   'ls': '162',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '741.0',
#   'sol': '23',
#   'terrestrial_date': '2012-08-29'},
#  {'id': '134',
#   'ls': '163',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '742.0',
#   'sol': '24',
#   'terrestrial_date': '2012-08-30'},
#  {'id': '145',
#   'ls': '163',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '743.0',
#   'sol': '25',
#   'terrestrial_date': '2012-08-31'},
#  {'id': '156',
#   'ls': '164',
#   'min_temp': '-76.0',
#   'month': '6',
#   'pressure': '745.0',
#   'sol': '26',
#   'terrestrial_date': '2012-09-01'},
#  {'id': '163',
#   'ls': '164',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '743.0',
#   'sol': '27',
#   'terrestrial_date': '2012-09-02'},
#  {'id': '170',
#   'ls': '165',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '745.0',
#   'sol': '28',
#   'terrestrial_date': '2012-09-03'},
#  {'id': '171',
#   'ls': '166',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '747.0',
#   'sol': '29',
#   'terrestrial_date': '2012-09-04'},
#  {'id': '172',
#   'ls': '166',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '747.0',
#   'sol': '30',
#   'terrestrial_date': '2012-09-05'},
#  {'id': '173',
#   'ls': '167',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '745.0',
#   'sol': '31',
#   'terrestrial_date': '2012-09-06'},
#  {'id': '175',
#   'ls': '168',
#   'min_temp': '-73.0',
#   'month': '6',
#   'pressure': '748.0',
#   'sol': '33',
#   'terrestrial_date': '2012-09-08'},
#  {'id': '176',
#   'ls': '168',
#   'min_temp': '-73.0',
#   'month': '6',
#   'pressure': '748.0',
#   'sol': '34',
#   'terrestrial_date': '2012-09-10'},
#  {'id': '177',
#   'ls': '169',
#   'min_temp': '-73.0',
#   'month': '6',
#   'pressure': '749.0',
#   'sol': '35',
#   'terrestrial_date': '2012-09-11'},
#  {'id': '178',
#   'ls': '169',
#   'min_temp': '-73.0',
#   'month': '6',
#   'pressure': '750.0',
#   'sol': '36',
#   'terrestrial_date': '2012-09-12'},
#  {'id': '179',
#   'ls': '170',
#   'min_temp': '-73.0',
#   'month': '6',
#   'pressure': '750.0',
#   'sol': '37',
#   'terrestrial_date': '2012-09-13'},
#  {'id': '180',
#   'ls': '171',
#   'min_temp': '-73.0',
#   'month': '6',
#   'pressure': '750.0',
#   'sol': '38',
#   'terrestrial_date': '2012-09-14'},
#  {'id': '181',
#   'ls': '171',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '751.0',
#   'sol': '39',
#   'terrestrial_date': '2012-09-15'},
#  {'id': '182',
#   'ls': '172',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '753.0',
#   'sol': '40',
#   'terrestrial_date': '2012-09-16'},
#  {'id': '183',
#   'ls': '172',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '753.0',
#   'sol': '41',
#   'terrestrial_date': '2012-09-17'},
#  {'id': '184',
#   'ls': '173',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '754.0',
#   'sol': '42',
#   'terrestrial_date': '2012-09-18'},
#  {'id': '185',
#   'ls': '173',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '756.0',
#   'sol': '43',
#   'terrestrial_date': '2012-09-19'},
#  {'id': '186',
#   'ls': '174',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '757.0',
#   'sol': '44',
#   'terrestrial_date': '2012-09-20'},
#  {'id': '187',
#   'ls': '175',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '758.0',
#   'sol': '45',
#   'terrestrial_date': '2012-09-21'},
#  {'id': '188',
#   'ls': '175',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '758.0',
#   'sol': '46',
#   'terrestrial_date': '2012-09-22'},
#  {'id': '189',
#   'ls': '176',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '758.0',
#   'sol': '47',
#   'terrestrial_date': '2012-09-23'},
#  {'id': '190',
#   'ls': '176',
#   'min_temp': '-75.0',
#   'month': '6',
#   'pressure': '759.0',
#   'sol': '48',
#   'terrestrial_date': '2012-09-24'},
#  {'id': '191',
#   'ls': '177',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '761.0',
#   'sol': '49',
#   'terrestrial_date': '2012-09-25'},
#  {'id': '192',
#   'ls': '177',
#   'min_temp': '-72.0',
#   'month': '6',
#   'pressure': '761.0',
#   'sol': '50',
#   'terrestrial_date': '2012-09-26'},
#  {'id': '193',
#   'ls': '178',
#   'min_temp': '-76.0',
#   'month': '6',
#   'pressure': '762.0',
#   'sol': '51',
#   'terrestrial_date': '2012-09-27'},
#  {'id': '194',
#   'ls': '179',
#   'min_temp': '-74.0',
#   'month': '6',
#   'pressure': '762.0',
#   'sol': '52',
#   'terrestrial_date': '2012-09-28'},
#  {'id': '195',
#   'ls': '179',
#   'min_temp': '-71.0',
#   'month': '6',
#   'pressure': '764.0',
#   'sol': '53',
#   'terrestrial_date': '2012-09-29'},
#  {'id': '196',
#   'ls': '180',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '766.0',
#   'sol': '54',
#   'terrestrial_date': '2012-09-30'},
#  {'id': '197',
#   'ls': '180',
#   'min_temp': '-74.0',
#   'month': '7',
#   'pressure': '766.0',
#   'sol': '55',
#   'terrestrial_date': '2012-10-01'},
#  {'id': '198',
#   'ls': '181',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '768.0',
#   'sol': '56',
#   'terrestrial_date': '2012-10-02'},
#  {'id': '199',
#   'ls': '181',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '769.0',
#   'sol': '57',
#   'terrestrial_date': '2012-10-03'},
#  {'id': '200',
#   'ls': '182',
#   'min_temp': '-74.0',
#   'month': '7',
#   'pressure': '769.0',
#   'sol': '58',
#   'terrestrial_date': '2012-10-04'},
#  {'id': '201',
#   'ls': '183',
#   'min_temp': '-76.0',
#   'month': '7',
#   'pressure': '771.0',
#   'sol': '59',
#   'terrestrial_date': '2012-10-05'},
#  {'id': '202',
#   'ls': '183',
#   'min_temp': '-75.0',
#   'month': '7',
#   'pressure': '772.0',
#   'sol': '60',
#   'terrestrial_date': '2012-10-06'},
#  {'id': '203',
#   'ls': '184',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '772.0',
#   'sol': '61',
#   'terrestrial_date': '2012-10-07'},
#  {'id': '204',
#   'ls': '184',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '774.0',
#   'sol': '62',
#   'terrestrial_date': '2012-10-08'},
#  {'id': '205',
#   'ls': '185',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '775.0',
#   'sol': '63',
#   'terrestrial_date': '2012-10-09'},
#  {'id': '206',
#   'ls': '186',
#   'min_temp': '-74.0',
#   'month': '7',
#   'pressure': '776.0',
#   'sol': '64',
#   'terrestrial_date': '2012-10-10'},
#  {'id': '207',
#   'ls': '186',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '777.0',
#   'sol': '65',
#   'terrestrial_date': '2012-10-11'},
#  {'id': '208',
#   'ls': '187',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '778.0',
#   'sol': '66',
#   'terrestrial_date': '2012-10-12'},
#  {'id': '209',
#   'ls': '187',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '780.0',
#   'sol': '67',
#   'terrestrial_date': '2012-10-13'},
#  {'id': '210',
#   'ls': '188',
#   'min_temp': '-71.0',
#   'month': '7',
#   'pressure': '781.0',
#   'sol': '68',
#   'terrestrial_date': '2012-10-14'},
#  {'id': '211',
#   'ls': '189',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '778.0',
#   'sol': '69',
#   'terrestrial_date': '2012-10-15'},
#  {'id': '212',
#   'ls': '189',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '783.0',
#   'sol': '70',
#   'terrestrial_date': '2012-10-17'},
#  {'id': '213',
#   'ls': '190',
#   'min_temp': '-71.0',
#   'month': '7',
#   'pressure': '784.0',
#   'sol': '71',
#   'terrestrial_date': '2012-10-18'},
#  {'id': '214',
#   'ls': '190',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '785.0',
#   'sol': '72',
#   'terrestrial_date': '2012-10-19'},
#  {'id': '215',
#   'ls': '191',
#   'min_temp': '-70.0',
#   'month': '7',
#   'pressure': '788.0',
#   'sol': '73',
#   'terrestrial_date': '2012-10-20'},
#  {'id': '216',
#   'ls': '192',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '790.0',
#   'sol': '74',
#   'terrestrial_date': '2012-10-21'},
#  {'id': '217',
#   'ls': '192',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '791.0',
#   'sol': '75',
#   'terrestrial_date': '2012-10-22'},
#  {'id': '218',
#   'ls': '193',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '792.0',
#   'sol': '76',
#   'terrestrial_date': '2012-10-23'},
#  {'id': '219',
#   'ls': '193',
#   'min_temp': '-71.0',
#   'month': '7',
#   'pressure': '792.0',
#   'sol': '77',
#   'terrestrial_date': '2012-10-24'},
#  {'id': '220',
#   'ls': '194',
#   'min_temp': '-71.0',
#   'month': '7',
#   'pressure': '793.0',
#   'sol': '78',
#   'terrestrial_date': '2012-10-25'},
#  {'id': '221',
#   'ls': '195',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '795.0',
#   'sol': '79',
#   'terrestrial_date': '2012-10-26'},
#  {'id': '222',
#   'ls': '195',
#   'min_temp': '-70.0',
#   'month': '7',
#   'pressure': '796.0',
#   'sol': '80',
#   'terrestrial_date': '2012-10-27'},
#  {'id': '223',
#   'ls': '196',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '798.0',
#   'sol': '81',
#   'terrestrial_date': '2012-10-28'},
#  {'id': '224',
#   'ls': '196',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '799.0',
#   'sol': '82',
#   'terrestrial_date': '2012-10-29'},
#  {'id': '225',
#   'ls': '197',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '801.0',
#   'sol': '83',
#   'terrestrial_date': '2012-10-30'},
#  {'id': '226',
#   'ls': '198',
#   'min_temp': '-70.0',
#   'month': '7',
#   'pressure': '801.0',
#   'sol': '84',
#   'terrestrial_date': '2012-10-31'},
#  {'id': '227',
#   'ls': '198',
#   'min_temp': '-71.0',
#   'month': '7',
#   'pressure': '805.0',
#   'sol': '85',
#   'terrestrial_date': '2012-11-01'},
#  {'id': '228',
#   'ls': '199',
#   'min_temp': '-71.0',
#   'month': '7',
#   'pressure': '808.0',
#   'sol': '86',
#   'terrestrial_date': '2012-11-02'},
#  {'id': '229',
#   'ls': '199',
#   'min_temp': '-70.0',
#   'month': '7',
#   'pressure': '808.0',
#   'sol': '87',
#   'terrestrial_date': '2012-11-03'},
#  {'id': '230',
#   'ls': '200',
#   'min_temp': '-70.0',
#   'month': '7',
#   'pressure': '811.0',
#   'sol': '88',
#   'terrestrial_date': '2012-11-04'},
#  {'id': '231',
#   'ls': '201',
#   'min_temp': '-73.0',
#   'month': '7',
#   'pressure': '813.0',
#   'sol': '89',
#   'terrestrial_date': '2012-11-05'},
#  {'id': '233',
#   'ls': '201',
#   'min_temp': '-71.0',
#   'month': '7',
#   'pressure': '813.0',
#   'sol': '90',
#   'terrestrial_date': '2012-11-06'},
#  {'id': '234',
#   'ls': '202',
#   'min_temp': '-74.0',
#   'month': '7',
#   'pressure': '817.0',
#   'sol': '91',
#   'terrestrial_date': '2012-11-07'},
#  {'id': '235',
#   'ls': '202',
#   'min_temp': '-74.0',
#   'month': '7',
#   'pressure': '820.0',
#   'sol': '92',
#   'terrestrial_date': '2012-11-08'},
#  {'id': '236',
#   'ls': '203',
#   'min_temp': '-72.0',
#   'month': '7',
#   'pressure': '819.0',
#   'sol': '93',
#   'terrestrial_date': '2012-11-09'},
#  {'id': '237',
#   'ls': '204',
#   'min_temp': '-70.0',
#   'month': '7',
#   'pressure': '822.0',
#   'sol': '94',
#   'terrestrial_date': '2012-11-10'},
#  {'id': '238',
#   'ls': '204',
#   'min_temp': '-68.0',
#   'month': '7',
#   'pressure': '822.0',
#   'sol': '95',
#   'terrestrial_date': '2012-11-11'},
#  {'id': '239',
#   'ls': '205',
#   'min_temp': '-71.0',
#   'month': '7',
#   'pressure': '826.0',
#   'sol': '96',
#   'terrestrial_date': '2012-11-12'},
#  {'id': '240',
#   'ls': '206',
#   'min_temp': '-68.0',
#   'month': '7',
#   'pressure': '828.0',
#   'sol': '97',
#   'terrestrial_date': '2012-11-13'},
#  {'id': '241',
#   'ls': '206',
#   'min_temp': '-68.0',
#   'month': '7',
#   'pressure': '828.0',
#   'sol': '98',
#   'terrestrial_date': '2012-11-14'},
#  {'id': '242',
#   'ls': '207',
#   'min_temp': '-68.0',
#   'month': '7',
#   'pressure': '829.0',
#   'sol': '99',
#   'terrestrial_date': '2012-11-15'},
#  {'id': '3',
#   'ls': '207',
#   'min_temp': '-66.0',
#   'month': '7',
#   'pressure': '829.0',
#   'sol': '100',
#   'terrestrial_date': '2012-11-16'},
#  {'id': '4',
#   'ls': '208',
#   'min_temp': '-65.0',
#   'month': '7',
#   'pressure': '830.0',
#   'sol': '101',
#   'terrestrial_date': '2012-11-17'},
#  {'id': '5',
#   'ls': '209',
#   'min_temp': '-67.0',
#   'month': '7',
#   'pressure': '833.0',
#   'sol': '102',
#   'terrestrial_date': '2012-11-18'},
#  {'id': '6',
#   'ls': '209',
#   'min_temp': '-66.0',
#   'month': '7',
#   'pressure': '836.0',
#   'sol': '103',
#   'terrestrial_date': '2012-11-19'},
#  {'id': '7',
#   'ls': '210',
#   'min_temp': '-67.0',
#   'month': '8',
#   'pressure': '838.0',
#   'sol': '104',
#   'terrestrial_date': '2012-11-20'},
#  {'id': '8',
#   'ls': '211',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '839.0',
#   'sol': '105',
#   'terrestrial_date': '2012-11-21'},
#  {'id': '9',
#   'ls': '211',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '841.0',
#   'sol': '106',
#   'terrestrial_date': '2012-11-23'},
#  {'id': '10',
#   'ls': '212',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '844.0',
#   'sol': '107',
#   'terrestrial_date': '2012-11-24'},
#  {'id': '11',
#   'ls': '212',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '845.0',
#   'sol': '108',
#   'terrestrial_date': '2012-11-25'},
#  {'id': '12',
#   'ls': '213',
#   'min_temp': '-64.0',
#   'month': '8',
#   'pressure': '844.0',
#   'sol': '109',
#   'terrestrial_date': '2012-11-26'},
#  {'id': '14',
#   'ls': '214',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '848.0',
#   'sol': '110',
#   'terrestrial_date': '2012-11-27'},
#  {'id': '15',
#   'ls': '214',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '849.0',
#   'sol': '111',
#   'terrestrial_date': '2012-11-28'},
#  {'id': '16',
#   'ls': '215',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '852.0',
#   'sol': '112',
#   'terrestrial_date': '2012-11-29'},
#  {'id': '17',
#   'ls': '216',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '857.0',
#   'sol': '113',
#   'terrestrial_date': '2012-11-30'},
#  {'id': '18',
#   'ls': '216',
#   'min_temp': '-69.0',
#   'month': '8',
#   'pressure': '857.0',
#   'sol': '114',
#   'terrestrial_date': '2012-12-01'},
#  {'id': '19',
#   'ls': '217',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '857.0',
#   'sol': '115',
#   'terrestrial_date': '2012-12-02'},
#  {'id': '20',
#   'ls': '217',
#   'min_temp': '-67.0',
#   'month': '8',
#   'pressure': '859.0',
#   'sol': '116',
#   'terrestrial_date': '2012-12-03'},
#  {'id': '21',
#   'ls': '218',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '861.0',
#   'sol': '117',
#   'terrestrial_date': '2012-12-04'},
#  {'id': '22',
#   'ls': '219',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '864.0',
#   'sol': '118',
#   'terrestrial_date': '2012-12-05'},
#  {'id': '23',
#   'ls': '219',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '866.0',
#   'sol': '119',
#   'terrestrial_date': '2012-12-06'},
#  {'id': '25',
#   'ls': '220',
#   'min_temp': '-67.0',
#   'month': '8',
#   'pressure': '867.0',
#   'sol': '120',
#   'terrestrial_date': '2012-12-07'},
#  {'id': '26',
#   'ls': '221',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '869.0',
#   'sol': '121',
#   'terrestrial_date': '2012-12-08'},
#  {'id': '27',
#   'ls': '221',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '869.0',
#   'sol': '122',
#   'terrestrial_date': '2012-12-09'},
#  {'id': '28',
#   'ls': '222',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '875.0',
#   'sol': '123',
#   'terrestrial_date': '2012-12-10'},
#  {'id': '29',
#   'ls': '223',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '876.0',
#   'sol': '124',
#   'terrestrial_date': '2012-12-11'},
#  {'id': '30',
#   'ls': '223',
#   'min_temp': '-68.0',
#   'month': '8',
#   'pressure': '880.0',
#   'sol': '125',
#   'terrestrial_date': '2012-12-12'},
#  {'id': '31',
#   'ls': '224',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '880.0',
#   'sol': '126',
#   'terrestrial_date': '2012-12-13'},
#  {'id': '32',
#   'ls': '224',
#   'min_temp': '-67.0',
#   'month': '8',
#   'pressure': '884.0',
#   'sol': '127',
#   'terrestrial_date': '2012-12-14'},
#  {'id': '33',
#   'ls': '225',
#   'min_temp': '-67.0',
#   'month': '8',
#   'pressure': '883.0',
#   'sol': '128',
#   'terrestrial_date': '2012-12-15'},
#  {'id': '34',
#   'ls': '226',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '886.0',
#   'sol': '129',
#   'terrestrial_date': '2012-12-16'},
#  {'id': '36',
#   'ls': '226',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '888.0',
#   'sol': '130',
#   'terrestrial_date': '2012-12-17'},
#  {'id': '37',
#   'ls': '227',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '889.0',
#   'sol': '131',
#   'terrestrial_date': '2012-12-18'},
#  {'id': '38',
#   'ls': '228',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '890.0',
#   'sol': '132',
#   'terrestrial_date': '2012-12-19'},
#  {'id': '39',
#   'ls': '228',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '891.0',
#   'sol': '133',
#   'terrestrial_date': '2012-12-20'},
#  {'id': '40',
#   'ls': '229',
#   'min_temp': '-67.0',
#   'month': '8',
#   'pressure': '893.0',
#   'sol': '134',
#   'terrestrial_date': '2012-12-21'},
#  {'id': '41',
#   'ls': '230',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '894.0',
#   'sol': '135',
#   'terrestrial_date': '2012-12-22'},
#  {'id': '42',
#   'ls': '230',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '897.0',
#   'sol': '136',
#   'terrestrial_date': '2012-12-23'},
#  {'id': '43',
#   'ls': '231',
#   'min_temp': '-64.0',
#   'month': '8',
#   'pressure': '896.0',
#   'sol': '137',
#   'terrestrial_date': '2012-12-24'},
#  {'id': '44',
#   'ls': '232',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '899.0',
#   'sol': '138',
#   'terrestrial_date': '2012-12-25'},
#  {'id': '45',
#   'ls': '232',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '899.0',
#   'sol': '139',
#   'terrestrial_date': '2012-12-26'},
#  {'id': '47',
#   'ls': '233',
#   'min_temp': '-66.0',
#   'month': '8',
#   'pressure': '903.0',
#   'sol': '140',
#   'terrestrial_date': '2012-12-27'},
#  {'id': '48',
#   'ls': '233',
#   'min_temp': '-64.0',
#   'month': '8',
#   'pressure': '904.0',
#   'sol': '141',
#   'terrestrial_date': '2012-12-28'},
#  {'id': '49',
#   'ls': '234',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '906.0',
#   'sol': '142',
#   'terrestrial_date': '2012-12-29'},
#  {'id': '50',
#   'ls': '235',
#   'min_temp': '-63.0',
#   'month': '8',
#   'pressure': '908.0',
#   'sol': '143',
#   'terrestrial_date': '2012-12-31'},
#  {'id': '51',
#   'ls': '235',
#   'min_temp': '-64.0',
#   'month': '8',
#   'pressure': '907.0',
#   'sol': '144',
#   'terrestrial_date': '2013-01-01'},
#  {'id': '52',
#   'ls': '236',
#   'min_temp': '-64.0',
#   'month': '8',
#   'pressure': '909.0',
#   'sol': '145',
#   'terrestrial_date': '2013-01-02'},
#  {'id': '53',
#   'ls': '237',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '908.0',
#   'sol': '146',
#   'terrestrial_date': '2013-01-03'},
#  {'id': '54',
#   'ls': '237',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '914.0',
#   'sol': '147',
#   'terrestrial_date': '2013-01-04'},
#  {'id': '55',
#   'ls': '238',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '912.0',
#   'sol': '148',
#   'terrestrial_date': '2013-01-05'},
#  {'id': '56',
#   'ls': '239',
#   'min_temp': '-65.0',
#   'month': '8',
#   'pressure': '914.0',
#   'sol': '149',
#   'terrestrial_date': '2013-01-06'},
#  {'id': '58',
#   'ls': '239',
#   'min_temp': '-64.0',
#   'month': '8',
#   'pressure': '913.0',
#   'sol': '150',
#   'terrestrial_date': '2013-01-07'},
#  {'id': '59',
#   'ls': '240',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '915.0',
#   'sol': '151',
#   'terrestrial_date': '2013-01-08'},
#  {'id': '60',
#   'ls': '241',
#   'min_temp': '-63.0',
#   'month': '9',
#   'pressure': '914.0',
#   'sol': '152',
#   'terrestrial_date': '2013-01-09'},
#  {'id': '61',
#   'ls': '241',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '915.0',
#   'sol': '153',
#   'terrestrial_date': '2013-01-10'},
#  {'id': '62',
#   'ls': '242',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '917.0',
#   'sol': '154',
#   'terrestrial_date': '2013-01-11'},
#  {'id': '63',
#   'ls': '243',
#   'min_temp': '-64.0',
#   'month': '9',
#   'pressure': '917.0',
#   'sol': '155',
#   'terrestrial_date': '2013-01-12'},
#  {'id': '64',
#   'ls': '243',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '922.0',
#   'sol': '156',
#   'terrestrial_date': '2013-01-13'},
#  {'id': '65',
#   'ls': '244',
#   'min_temp': '-64.0',
#   'month': '9',
#   'pressure': '920.0',
#   'sol': '157',
#   'terrestrial_date': '2013-01-14'},
#  {'id': '66',
#   'ls': '245',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '922.0',
#   'sol': '158',
#   'terrestrial_date': '2013-01-15'},
#  {'id': '67',
#   'ls': '245',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '918.0',
#   'sol': '159',
#   'terrestrial_date': '2013-01-16'},
#  {'id': '69',
#   'ls': '246',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '919.0',
#   'sol': '160',
#   'terrestrial_date': '2013-01-17'},
#  {'id': '70',
#   'ls': '246',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '919.0',
#   'sol': '161',
#   'terrestrial_date': '2013-01-18'},
#  {'id': '71',
#   'ls': '247',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '919.0',
#   'sol': '162',
#   'terrestrial_date': '2013-01-19'},
#  {'id': '72',
#   'ls': '248',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '919.0',
#   'sol': '163',
#   'terrestrial_date': '2013-01-20'},
#  {'id': '73',
#   'ls': '248',
#   'min_temp': '-64.0',
#   'month': '9',
#   'pressure': '919.0',
#   'sol': '164',
#   'terrestrial_date': '2013-01-21'},
#  {'id': '74',
#   'ls': '249',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '922.0',
#   'sol': '165',
#   'terrestrial_date': '2013-01-22'},
#  {'id': '75',
#   'ls': '250',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '922.0',
#   'sol': '166',
#   'terrestrial_date': '2013-01-23'},
#  {'id': '76',
#   'ls': '250',
#   'min_temp': '-65.0',
#   'month': '9',
#   'pressure': '920.0',
#   'sol': '167',
#   'terrestrial_date': '2013-01-24'},
#  {'id': '77',
#   'ls': '251',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '923.0',
#   'sol': '168',
#   'terrestrial_date': '2013-01-25'},
#  {'id': '78',
#   'ls': '252',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '922.0',
#   'sol': '169',
#   'terrestrial_date': '2013-01-26'},
#  {'id': '80',
#   'ls': '252',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '925.0',
#   'sol': '170',
#   'terrestrial_date': '2013-01-27'},
#  {'id': '81',
#   'ls': '253',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '925.0',
#   'sol': '171',
#   'terrestrial_date': '2013-01-28'},
#  {'id': '82',
#   'ls': '254',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '923.0',
#   'sol': '172',
#   'terrestrial_date': '2013-01-29'},
#  {'id': '83',
#   'ls': '254',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '920.0',
#   'sol': '173',
#   'terrestrial_date': '2013-01-30'},
#  {'id': '84',
#   'ls': '255',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '921.0',
#   'sol': '174',
#   'terrestrial_date': '2013-01-31'},
#  {'id': '85',
#   'ls': '256',
#   'min_temp': '-68.0',
#   'month': '9',
#   'pressure': '921.0',
#   'sol': '175',
#   'terrestrial_date': '2013-02-01'},
#  {'id': '86',
#   'ls': '256',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '920.0',
#   'sol': '176',
#   'terrestrial_date': '2013-02-02'},
#  {'id': '87',
#   'ls': '257',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '921.0',
#   'sol': '177',
#   'terrestrial_date': '2013-02-03'},
#  {'id': '88',
#   'ls': '258',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '920.0',
#   'sol': '178',
#   'terrestrial_date': '2013-02-04'},
#  {'id': '89',
#   'ls': '258',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '920.0',
#   'sol': '179',
#   'terrestrial_date': '2013-02-06'},
#  {'id': '91',
#   'ls': '259',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '919.0',
#   'sol': '180',
#   'terrestrial_date': '2013-02-07'},
#  {'id': '92',
#   'ls': '260',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '918.0',
#   'sol': '181',
#   'terrestrial_date': '2013-02-08'},
#  {'id': '93',
#   'ls': '260',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '921.0',
#   'sol': '182',
#   'terrestrial_date': '2013-02-09'},
#  {'id': '94',
#   'ls': '261',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '921.0',
#   'sol': '183',
#   'terrestrial_date': '2013-02-10'},
#  {'id': '95',
#   'ls': '261',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '923.0',
#   'sol': '184',
#   'terrestrial_date': '2013-02-11'},
#  {'id': '96',
#   'ls': '262',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '923.0',
#   'sol': '185',
#   'terrestrial_date': '2013-02-12'},
#  {'id': '97',
#   'ls': '263',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '922.0',
#   'sol': '186',
#   'terrestrial_date': '2013-02-13'},
#  {'id': '98',
#   'ls': '263',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '921.0',
#   'sol': '187',
#   'terrestrial_date': '2013-02-14'},
#  {'id': '99',
#   'ls': '264',
#   'min_temp': '-68.0',
#   'month': '9',
#   'pressure': '920.0',
#   'sol': '188',
#   'terrestrial_date': '2013-02-15'},
#  {'id': '100',
#   'ls': '265',
#   'min_temp': '-68.0',
#   'month': '9',
#   'pressure': '920.0',
#   'sol': '189',
#   'terrestrial_date': '2013-02-16'},
#  {'id': '102',
#   'ls': '265',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '917.0',
#   'sol': '190',
#   'terrestrial_date': '2013-02-17'},
#  {'id': '103',
#   'ls': '266',
#   'min_temp': '-67.0',
#   'month': '9',
#   'pressure': '921.0',
#   'sol': '191',
#   'terrestrial_date': '2013-02-18'},
#  {'id': '106',
#   'ls': '269',
#   'min_temp': '-66.0',
#   'month': '9',
#   'pressure': '916.0',
#   'sol': '196',
#   'terrestrial_date': '2013-02-23'},
#  {'id': '107',
#   'ls': '270',
#   'min_temp': '-68.0',
#   'month': '10',
#   'pressure': '915.0',
#   'sol': '197',
#   'terrestrial_date': '2013-02-24'},
#  {'id': '108',
#   'ls': '271',
#   'min_temp': '-67.0',
#   'month': '10',
#   'pressure': '914.0',
#   'sol': '198',
#   'terrestrial_date': '2013-02-25'},
#  {'id': '109',
#   'ls': '271',
#   'min_temp': '-66.0',
#   'month': '10',
#   'pressure': '917.0',
#   'sol': '199',
#   'terrestrial_date': '2013-02-26'},
#  {'id': '116',
#   'ls': '287',
#   'min_temp': '-71.0',
#   'month': '10',
#   'pressure': '895.0',
#   'sol': '223',
#   'terrestrial_date': '2013-03-23'},
#  {'id': '117',
#   'ls': '287',
#   'min_temp': '-69.0',
#   'month': '10',
#   'pressure': '894.0',
#   'sol': '224',
#   'terrestrial_date': '2013-03-24'},
#  {'id': '118',
#   'ls': '288',
#   'min_temp': '-71.0',
#   'month': '10',
#   'pressure': '894.0',
#   'sol': '225',
#   'terrestrial_date': '2013-03-25'},
#  {'id': '119',
#   'ls': '288',
#   'min_temp': '-70.0',
#   'month': '10',
#   'pressure': '894.0',
#   'sol': '226',
#   'terrestrial_date': '2013-03-26'},
#  {'id': '120',
#   'ls': '289',
#   'min_temp': '-70.0',
#   'month': '10',
#   'pressure': '892.0',
#   'sol': '227',
#   'terrestrial_date': '2013-03-27'},
#  {'id': '121',
#   'ls': '290',
#   'min_temp': '-71.0',
#   'month': '10',
#   'pressure': '894.0',
#   'sol': '228',
#   'terrestrial_date': '2013-03-28'},
#  {'id': '122',
#   'ls': '290',
#   'min_temp': '-69.0',
#   'month': '10',
#   'pressure': '894.0',
#   'sol': '229',
#   'terrestrial_date': '2013-03-29'},
#  {'id': '124',
#   'ls': '291',
#   'min_temp': '-69.0',
#   'month': '10',
#   'pressure': '888.0',
#   'sol': '230',
#   'terrestrial_date': '2013-03-30'},
#  {'id': '125',
#   'ls': '292',
#   'min_temp': '-71.0',
#   'month': '10',
#   'pressure': '890.0',
#   'sol': '231',
#   'terrestrial_date': '2013-03-31'},
#  {'id': '126',
#   'ls': '292',
#   'min_temp': '-69.0',
#   'month': '10',
#   'pressure': '888.0',
#   'sol': '232',
#   'terrestrial_date': '2013-04-01'},
#  {'id': '127',
#   'ls': '293',
#   'min_temp': '-69.0',
#   'month': '10',
#   'pressure': '889.0',
#   'sol': '233',
#   'terrestrial_date': '2013-04-02'},
#  {'id': '128',
#   'ls': '293',
#   'min_temp': '-69.0',
#   'month': '10',
#   'pressure': '890.0',
#   'sol': '234',
#   'terrestrial_date': '2013-04-03'},
#  {'id': '129',
#   'ls': '294',
#   'min_temp': '-70.0',
#   'month': '10',
#   'pressure': '886.0',
#   'sol': '235',
#   'terrestrial_date': '2013-04-04'},
#  {'id': '130',
#   'ls': '295',
#   'min_temp': '-72.0',
#   'month': '10',
#   'pressure': '886.0',
#   'sol': '236',
#   'terrestrial_date': '2013-04-05'},
#  {'id': '131',
#   'ls': '295',
#   'min_temp': '-71.0',
#   'month': '10',
#   'pressure': '883.0',
#   'sol': '237',
#   'terrestrial_date': '2013-04-06'},
#  {'id': '132',
#   'ls': '296',
#   'min_temp': '-70.0',
#   'month': '10',
#   'pressure': '885.0',
#   'sol': '238',
#   'terrestrial_date': '2013-04-07'},
#  {'id': '133',
#   'ls': '297',
#   'min_temp': '-73.0',
#   'month': '10',
#   'pressure': '885.0',
#   'sol': '239',
#   'terrestrial_date': '2013-04-08'},
#  {'id': '135',
#   'ls': '297',
#   'min_temp': '-70.0',
#   'month': '10',
#   'pressure': '884.0',
#   'sol': '240',
#   'terrestrial_date': '2013-04-09'},
#  {'id': '136',
#   'ls': '298',
#   'min_temp': '-72.0',
#   'month': '10',
#   'pressure': '884.0',
#   'sol': '241',
#   'terrestrial_date': '2013-04-10'},
#  {'id': '137',
#   'ls': '298',
#   'min_temp': '-70.0',
#   'month': '10',
#   'pressure': '881.0',
#   'sol': '242',
#   'terrestrial_date': '2013-04-11'},
#  {'id': '138',
#   'ls': '299',
#   'min_temp': '-71.0',
#   'month': '10',
#   'pressure': '884.0',
#   'sol': '243',
#   'terrestrial_date': '2013-04-12'},
#  {'id': '139',
#   'ls': '300',
#   'min_temp': '-69.0',
#   'month': '11',
#   'pressure': '878.0',
#   'sol': '244',
#   'terrestrial_date': '2013-04-13'},
#  {'id': '140',
#   'ls': '300',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '879.0',
#   'sol': '245',
#   'terrestrial_date': '2013-04-14'},
#  {'id': '141',
#   'ls': '301',
#   'min_temp': '-73.0',
#   'month': '11',
#   'pressure': '878.0',
#   'sol': '246',
#   'terrestrial_date': '2013-04-15'},
#  {'id': '142',
#   'ls': '301',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '873.0',
#   'sol': '247',
#   'terrestrial_date': '2013-04-16'},
#  {'id': '143',
#   'ls': '302',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '877.0',
#   'sol': '248',
#   'terrestrial_date': '2013-04-17'},
#  {'id': '144',
#   'ls': '303',
#   'min_temp': '-69.0',
#   'month': '11',
#   'pressure': '873.0',
#   'sol': '249',
#   'terrestrial_date': '2013-04-18'},
#  {'id': '146',
#   'ls': '303',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '877.0',
#   'sol': '250',
#   'terrestrial_date': '2013-04-19'},
#  {'id': '147',
#   'ls': '304',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '876.0',
#   'sol': '251',
#   'terrestrial_date': '2013-04-20'},
#  {'id': '148',
#   'ls': '304',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '874.0',
#   'sol': '252',
#   'terrestrial_date': '2013-04-22'},
#  {'id': '149',
#   'ls': '305',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '877.0',
#   'sol': '253',
#   'terrestrial_date': '2013-04-23'},
#  {'id': '150',
#   'ls': '306',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '871.0',
#   'sol': '254',
#   'terrestrial_date': '2013-04-24'},
#  {'id': '151',
#   'ls': '306',
#   'min_temp': '-69.0',
#   'month': '11',
#   'pressure': '877.0',
#   'sol': '255',
#   'terrestrial_date': '2013-04-25'},
#  {'id': '152',
#   'ls': '307',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '871.0',
#   'sol': '256',
#   'terrestrial_date': '2013-04-26'},
#  {'id': '153',
#   'ls': '308',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '871.0',
#   'sol': '257',
#   'terrestrial_date': '2013-04-27'},
#  {'id': '154',
#   'ls': '308',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '869.0',
#   'sol': '258',
#   'terrestrial_date': '2013-04-28'},
#  {'id': '155',
#   'ls': '309',
#   'min_temp': '-72.0',
#   'month': '11',
#   'pressure': '871.0',
#   'sol': '259',
#   'terrestrial_date': '2013-04-29'},
#  {'id': '157',
#   'ls': '309',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '875.0',
#   'sol': '260',
#   'terrestrial_date': '2013-04-30'},
#  {'id': '158',
#   'ls': '310',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '868.0',
#   'sol': '261',
#   'terrestrial_date': '2013-05-01'},
#  {'id': '161',
#   'ls': '314',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '864.0',
#   'sol': '268',
#   'terrestrial_date': '2013-05-08'},
#  {'id': '162',
#   'ls': '315',
#   'min_temp': '-72.0',
#   'month': '11',
#   'pressure': '866.0',
#   'sol': '269',
#   'terrestrial_date': '2013-05-09'},
#  {'id': '164',
#   'ls': '315',
#   'min_temp': '-67.0',
#   'month': '11',
#   'pressure': '863.0',
#   'sol': '270',
#   'terrestrial_date': '2013-05-10'},
#  {'id': '165',
#   'ls': '316',
#   'min_temp': '-69.0',
#   'month': '11',
#   'pressure': '864.0',
#   'sol': '271',
#   'terrestrial_date': '2013-05-11'},
#  {'id': '166',
#   'ls': '316',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '864.0',
#   'sol': '272',
#   'terrestrial_date': '2013-05-12'},
#  {'id': '167',
#   'ls': '317',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '861.0',
#   'sol': '273',
#   'terrestrial_date': '2013-05-13'},
#  {'id': '168',
#   'ls': '318',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '861.0',
#   'sol': '274',
#   'terrestrial_date': '2013-05-14'},
#  {'id': '169',
#   'ls': '318',
#   'min_temp': '-67.0',
#   'month': '11',
#   'pressure': '860.0',
#   'sol': '275',
#   'terrestrial_date': '2013-05-15'},
#  {'id': '244',
#   'ls': '319',
#   'min_temp': '-69.0',
#   'month': '11',
#   'pressure': '858.0',
#   'sol': '276',
#   'terrestrial_date': '2013-05-16'},
#  {'id': '245',
#   'ls': '319',
#   'min_temp': '-69.0',
#   'month': '11',
#   'pressure': '857.0',
#   'sol': '277',
#   'terrestrial_date': '2013-05-17'},
#  {'id': '246',
#   'ls': '320',
#   'min_temp': '-67.0',
#   'month': '11',
#   'pressure': '855.0',
#   'sol': '278',
#   'terrestrial_date': '2013-05-18'},
#  {'id': '247',
#   'ls': '321',
#   'min_temp': '-68.0',
#   'month': '11',
#   'pressure': '856.0',
#   'sol': '279',
#   'terrestrial_date': '2013-05-19'},
#  {'id': '248',
#   'ls': '321',
#   'min_temp': '-69.0',
#   'month': '11',
#   'pressure': '856.0',
#   'sol': '280',
#   'terrestrial_date': '2013-05-20'},
#  {'id': '249',
#   'ls': '322',
#   'min_temp': '-68.0',
#   'month': '11',
#   'pressure': '855.0',
#   'sol': '281',
#   'terrestrial_date': '2013-05-21'},
#  {'id': '250',
#   'ls': '322',
#   'min_temp': '-72.0',
#   'month': '11',
#   'pressure': '856.0',
#   'sol': '282',
#   'terrestrial_date': '2013-05-22'},
#  {'id': '251',
#   'ls': '323',
#   'min_temp': '-68.0',
#   'month': '11',
#   'pressure': '854.0',
#   'sol': '283',
#   'terrestrial_date': '2013-05-23'},
#  {'id': '252',
#   'ls': '323',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '854.0',
#   'sol': '284',
#   'terrestrial_date': '2013-05-24'},
#  {'id': '253',
#   'ls': '324',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '852.0',
#   'sol': '285',
#   'terrestrial_date': '2013-05-25'},
#  {'id': '254',
#   'ls': '325',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '854.0',
#   'sol': '286',
#   'terrestrial_date': '2013-05-26'},
#  {'id': '255',
#   'ls': '325',
#   'min_temp': '-72.0',
#   'month': '11',
#   'pressure': '856.0',
#   'sol': '287',
#   'terrestrial_date': '2013-05-27'},
#  {'id': '256',
#   'ls': '326',
#   'min_temp': '-69.0',
#   'month': '11',
#   'pressure': '854.0',
#   'sol': '288',
#   'terrestrial_date': '2013-05-29'},
#  {'id': '257',
#   'ls': '326',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '854.0',
#   'sol': '289',
#   'terrestrial_date': '2013-05-30'},
#  {'id': '258',
#   'ls': '327',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '853.0',
#   'sol': '290',
#   'terrestrial_date': '2013-05-31'},
#  {'id': '259',
#   'ls': '327',
#   'min_temp': '-70.0',
#   'month': '11',
#   'pressure': '853.0',
#   'sol': '291',
#   'terrestrial_date': '2013-06-01'},
#  {'id': '260',
#   'ls': '328',
#   'min_temp': '-71.0',
#   'month': '11',
#   'pressure': '853.0',
#   'sol': '292',
#   'terrestrial_date': '2013-06-02'},
#  {'id': '261',
#   'ls': '329',
#   'min_temp': '-72.0',
#   'month': '11',
#   'pressure': '850.0',
#   'sol': '293',
#   'terrestrial_date': '2013-06-03'},
#  {'id': '262',
#   'ls': '329',
#   'min_temp': '-72.0',
#   'month': '11',
#   'pressure': '852.0',
#   'sol': '294',
#   'terrestrial_date': '2013-06-04'},
#  {'id': '263',
#   'ls': '330',
#   'min_temp': '-71.0',
#   'month': '12',
#   'pressure': '853.0',
#   'sol': '295',
#   'terrestrial_date': '2013-06-05'},
#  {'id': '264',
#   'ls': '330',
#   'min_temp': '-71.0',
#   'month': '12',
#   'pressure': '850.0',
#   'sol': '296',
#   'terrestrial_date': '2013-06-06'},
#  {'id': '265',
#   'ls': '331',
#   'min_temp': '-72.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '297',
#   'terrestrial_date': '2013-06-07'},
#  {'id': '266',
#   'ls': '331',
#   'min_temp': '-72.0',
#   'month': '12',
#   'pressure': '850.0',
#   'sol': '298',
#   'terrestrial_date': '2013-06-08'},
#  {'id': '267',
#   'ls': '332',
#   'min_temp': '-71.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '299',
#   'terrestrial_date': '2013-06-09'},
#  {'id': '286',
#   'ls': '333',
#   'min_temp': '-72.0',
#   'month': '12',
#   'pressure': '852.0',
#   'sol': '300',
#   'terrestrial_date': '2013-06-10'},
#  {'id': '276',
#   'ls': '333',
#   'min_temp': '-73.0',
#   'month': '12',
#   'pressure': '852.0',
#   'sol': '301',
#   'terrestrial_date': '2013-06-11'},
#  {'id': '287',
#   'ls': '334',
#   'min_temp': '-71.0',
#   'month': '12',
#   'pressure': '850.0',
#   'sol': '302',
#   'terrestrial_date': '2013-06-12'},
#  {'id': '283',
#   'ls': '334',
#   'min_temp': '-71.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '303',
#   'terrestrial_date': '2013-06-13'},
#  {'id': '281',
#   'ls': '335',
#   'min_temp': '-70.0',
#   'month': '12',
#   'pressure': '848.0',
#   'sol': '304',
#   'terrestrial_date': '2013-06-14'},
#  {'id': '275',
#   'ls': '335',
#   'min_temp': '-71.0',
#   'month': '12',
#   'pressure': '847.0',
#   'sol': '305',
#   'terrestrial_date': '2013-06-15'},
#  {'id': '280',
#   'ls': '336',
#   'min_temp': '-71.0',
#   'month': '12',
#   'pressure': '848.0',
#   'sol': '306',
#   'terrestrial_date': '2013-06-16'},
#  {'id': '279',
#   'ls': '336',
#   'min_temp': '-72.0',
#   'month': '12',
#   'pressure': '851.0',
#   'sol': '307',
#   'terrestrial_date': '2013-06-17'},
#  {'id': '282',
#   'ls': '337',
#   'min_temp': '-73.0',
#   'month': '12',
#   'pressure': '850.0',
#   'sol': '308',
#   'terrestrial_date': '2013-06-18'},
#  {'id': '284',
#   'ls': '338',
#   'min_temp': '-72.0',
#   'month': '12',
#   'pressure': '848.0',
#   'sol': '309',
#   'terrestrial_date': '2013-06-19'},
#  {'id': '278',
#   'ls': '338',
#   'min_temp': '-71.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '310',
#   'terrestrial_date': '2013-06-20'},
#  {'id': '277',
#   'ls': '339',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '846.0',
#   'sol': '311',
#   'terrestrial_date': '2013-06-21'},
#  {'id': '285',
#   'ls': '339',
#   'min_temp': '-71.0',
#   'month': '12',
#   'pressure': '845.0',
#   'sol': '312',
#   'terrestrial_date': '2013-06-22'},
#  {'id': '274',
#   'ls': '340',
#   'min_temp': '-77.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '313',
#   'terrestrial_date': '2013-06-23'},
#  {'id': '272',
#   'ls': '340',
#   'min_temp': '-73.0',
#   'month': '12',
#   'pressure': '848.0',
#   'sol': '314',
#   'terrestrial_date': '2013-06-24'},
#  {'id': '273',
#   'ls': '341',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '850.0',
#   'sol': '315',
#   'terrestrial_date': '2013-06-25'},
#  {'id': '288',
#   'ls': '341',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '851.0',
#   'sol': '316',
#   'terrestrial_date': '2013-06-26'},
#  {'id': '268',
#   'ls': '342',
#   'min_temp': '-72.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '317',
#   'terrestrial_date': '2013-06-27'},
#  {'id': '270',
#   'ls': '342',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '318',
#   'terrestrial_date': '2013-06-28'},
#  {'id': '271',
#   'ls': '343',
#   'min_temp': '-73.0',
#   'month': '12',
#   'pressure': '847.0',
#   'sol': '319',
#   'terrestrial_date': '2013-06-29'},
#  {'id': '269',
#   'ls': '344',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '846.0',
#   'sol': '320',
#   'terrestrial_date': '2013-06-30'},
#  {'id': '289',
#   'ls': '344',
#   'min_temp': '-75.0',
#   'month': '12',
#   'pressure': '847.0',
#   'sol': '321',
#   'terrestrial_date': '2013-07-01'},
#  {'id': '291',
#   'ls': '345',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '322',
#   'terrestrial_date': '2013-07-02'},
#  {'id': '290',
#   'ls': '345',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '847.0',
#   'sol': '323',
#   'terrestrial_date': '2013-07-03'},
#  {'id': '292',
#   'ls': '346',
#   'min_temp': '-75.0',
#   'month': '12',
#   'pressure': '850.0',
#   'sol': '324',
#   'terrestrial_date': '2013-07-04'},
#  {'id': '294',
#   'ls': '346',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '847.0',
#   'sol': '325',
#   'terrestrial_date': '2013-07-06'},
#  {'id': '295',
#   'ls': '347',
#   'min_temp': '-72.0',
#   'month': '12',
#   'pressure': '848.0',
#   'sol': '326',
#   'terrestrial_date': '2013-07-07'},
#  {'id': '296',
#   'ls': '347',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '848.0',
#   'sol': '327',
#   'terrestrial_date': '2013-07-08'},
#  {'id': '293',
#   'ls': '348',
#   'min_temp': '-75.0',
#   'month': '12',
#   'pressure': '847.0',
#   'sol': '328',
#   'terrestrial_date': '2013-07-09'},
#  {'id': '298',
#   'ls': '348',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '847.0',
#   'sol': '329',
#   'terrestrial_date': '2013-07-10'},
#  {'id': '297',
#   'ls': '349',
#   'min_temp': '-75.0',
#   'month': '12',
#   'pressure': '848.0',
#   'sol': '330',
#   'terrestrial_date': '2013-07-11'},
#  {'id': '303',
#   'ls': '349',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '848.0',
#   'sol': '331',
#   'terrestrial_date': '2013-07-12'},
#  {'id': '300',
#   'ls': '350',
#   'min_temp': '-76.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '332',
#   'terrestrial_date': '2013-07-13'},
#  {'id': '299',
#   'ls': '350',
#   'min_temp': '-75.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '333',
#   'terrestrial_date': '2013-07-14'},
#  {'id': '301',
#   'ls': '351',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '852.0',
#   'sol': '334',
#   'terrestrial_date': '2013-07-15'},
#  {'id': '302',
#   'ls': '352',
#   'min_temp': '-76.0',
#   'month': '12',
#   'pressure': '852.0',
#   'sol': '335',
#   'terrestrial_date': '2013-07-16'},
#  {'id': '305',
#   'ls': '352',
#   'min_temp': '-76.0',
#   'month': '12',
#   'pressure': '852.0',
#   'sol': '336',
#   'terrestrial_date': '2013-07-17'},
#  {'id': '304',
#   'ls': '353',
#   'min_temp': '-75.0',
#   'month': '12',
#   'pressure': '853.0',
#   'sol': '337',
#   'terrestrial_date': '2013-07-18'},
#  {'id': '306',
#   'ls': '353',
#   'min_temp': '-78.0',
#   'month': '12',
#   'pressure': '848.0',
#   'sol': '338',
#   'terrestrial_date': '2013-07-19'},
#  {'id': '308',
#   'ls': '354',
#   'min_temp': '-76.0',
#   'month': '12',
#   'pressure': '849.0',
#   'sol': '339',
#   'terrestrial_date': '2013-07-20'},
#  {'id': '307',
#   'ls': '354',
#   'min_temp': '-76.0',
#   'month': '12',
#   'pressure': '851.0',
#   'sol': '340',
#   'terrestrial_date': '2013-07-21'},
#  {'id': '310',
#   'ls': '355',
#   'min_temp': '-77.0',
#   'month': '12',
#   'pressure': '852.0',
#   'sol': '341',
#   'terrestrial_date': '2013-07-22'},
#  {'id': '309',
#   'ls': '355',
#   'min_temp': '-76.0',
#   'month': '12',
#   'pressure': '851.0',
#   'sol': '342',
#   'terrestrial_date': '2013-07-23'},
#  {'id': '311',
#   'ls': '356',
#   'min_temp': '-77.0',
#   'month': '12',
#   'pressure': '850.0',
#   'sol': '343',
#   'terrestrial_date': '2013-07-24'},
#  {'id': '317',
#   'ls': '356',
#   'min_temp': '-77.0',
#   'month': '12',
#   'pressure': '851.0',
#   'sol': '344',
#   'terrestrial_date': '2013-07-25'},
#  {'id': '312',
#   'ls': '357',
#   'min_temp': '-77.0',
#   'month': '12',
#   'pressure': '853.0',
#   'sol': '345',
#   'terrestrial_date': '2013-07-26'},
#  {'id': '314',
#   'ls': '357',
#   'min_temp': '-76.0',
#   'month': '12',
#   'pressure': '853.0',
#   'sol': '346',
#   'terrestrial_date': '2013-07-27'},
#  {'id': '313',
#   'ls': '358',
#   'min_temp': '-77.0',
#   'month': '12',
#   'pressure': '851.0',
#   'sol': '347',
#   'terrestrial_date': '2013-07-28'},
#  {'id': '315',
#   'ls': '358',
#   'min_temp': '-74.0',
#   'month': '12',
#   'pressure': '850.0',
#   'sol': '348',
#   'terrestrial_date': '2013-07-29'},
#  {'id': '316',
#   'ls': '359',
#   'min_temp': '-75.0',
#   'month': '12',
#   'pressure': '852.0',
#   'sol': '349',
#   'terrestrial_date': '2013-07-30'},
#  {'id': '318',
#   'ls': '359',
#   'min_temp': '-76.0',
#   'month': '12',
#   'pressure': '853.0',
#   'sol': '350',
#   'terrestrial_date': '2013-07-31'},
#  {'id': '320',
#   'ls': '0',
#   'min_temp': '-75.0',
#   'month': '1',
#   'pressure': '853.0',
#   'sol': '351',
#   'terrestrial_date': '2013-08-01'},
#  {'id': '319',
#   'ls': '0',
#   'min_temp': '-77.0',
#   'month': '1',
#   'pressure': '854.0',
#   'sol': '352',
#   'terrestrial_date': '2013-08-02'},
#  {'id': '323',
#   'ls': '1',
#   'min_temp': '-75.0',
#   'month': '1',
#   'pressure': '855.0',
#   'sol': '353',
#   'terrestrial_date': '2013-08-03'},
#  {'id': '322',
#   'ls': '1',
#   'min_temp': '-75.0',
#   'month': '1',
#   'pressure': '857.0',
#   'sol': '354',
#   'terrestrial_date': '2013-08-04'},
#  {'id': '321',
#   'ls': '2',
#   'min_temp': '-75.0',
#   'month': '1',
#   'pressure': '857.0',
#   'sol': '355',
#   'terrestrial_date': '2013-08-05'},
#  {'id': '324',
#   'ls': '2',
#   'min_temp': '-77.0',
#   'month': '1',
#   'pressure': '856.0',
#   'sol': '356',
#   'terrestrial_date': '2013-08-06'},
#  {'id': '325',
#   'ls': '3',
#   'min_temp': '-76.0',
#   'month': '1',
#   'pressure': '857.0',
#   'sol': '357',
#   'terrestrial_date': '2013-08-07'},
#  {'id': '326',
#   'ls': '7',
#   'min_temp': '-76.0',
#   'month': '1',
#   'pressure': '861.0',
#   'sol': '366',
#   'terrestrial_date': '2013-08-17'},
#  {'id': '328',
#   'ls': '8',
#   'min_temp': '-76.0',
#   'month': '1',
#   'pressure': '862.0',
#   'sol': '367',
#   'terrestrial_date': '2013-08-18'},
#  {'id': '330',
#   'ls': '8',
#   'min_temp': '-77.0',
#   'month': '1',
#   'pressure': '863.0',
#   'sol': '368',
#   'terrestrial_date': '2013-08-19'},
#  {'id': '331',
#   'ls': '9',
#   'min_temp': '-75.0',
#   'month': '1',
#   'pressure': '865.0',
#   'sol': '369',
#   'terrestrial_date': '2013-08-20'},
#  {'id': '332',
#   'ls': '9',
#   'min_temp': '-79.0',
#   'month': '1',
#   'pressure': '865.0',
#   'sol': '370',
#   'terrestrial_date': '2013-08-21'},
#  {'id': '333',
#   'ls': '10',
#   'min_temp': '-77.0',
#   'month': '1',
#   'pressure': '865.0',
#   'sol': '371',
#   'terrestrial_date': '2013-08-22'},
#  {'id': '334',
#   'ls': '10',
#   'min_temp': '-76.0',
#   'month': '1',
#   'pressure': '866.0',
#   'sol': '372',
#   'terrestrial_date': '2013-08-23'},
#  {'id': '335',
#   'ls': '11',
#   'min_temp': '-79.0',
#   'month': '1',
#   'pressure': '866.0',
#   'sol': '373',
#   'terrestrial_date': '2013-08-24'},
#  {'id': '337',
#   'ls': '11',
#   'min_temp': '-79.0',
#   'month': '1',
#   'pressure': '866.0',
#   'sol': '374',
#   'terrestrial_date': '2013-08-25'},
#  {'id': '336',
#   'ls': '12',
#   'min_temp': '-77.0',
#   'month': '1',
#   'pressure': '867.0',
#   'sol': '375',
#   'terrestrial_date': '2013-08-26'},
#  {'id': '340',
#   'ls': '12',
#   'min_temp': '-78.0',
#   'month': '1',
#   'pressure': '870.0',
#   'sol': '376',
#   'terrestrial_date': '2013-08-27'},
#  {'id': '338',
#   'ls': '13',
#   'min_temp': '-78.0',
#   'month': '1',
#   'pressure': '870.0',
#   'sol': '377',
#   'terrestrial_date': '2013-08-28'},
#  {'id': '339',
#   'ls': '13',
#   'min_temp': '-78.0',
#   'month': '1',
#   'pressure': '869.0',
#   'sol': '378',
#   'terrestrial_date': '2013-08-29'},
#  {'id': '341',
#   'ls': '14',
#   'min_temp': '-79.0',
#   'month': '1',
#   'pressure': '870.0',
#   'sol': '379',
#   'terrestrial_date': '2013-08-30'},
#  {'id': '343',
#   'ls': '14',
#   'min_temp': '-79.0',
#   'month': '1',
#   'pressure': '870.0',
#   'sol': '380',
#   'terrestrial_date': '2013-08-31'},
#  {'id': '345',
#   'ls': '15',
#   'min_temp': '-79.0',
#   'month': '1',
#   'pressure': '871.0',
#   'sol': '381',
#   'terrestrial_date': '2013-09-01'},
#  {'id': '344',
#   'ls': '15',
#   'min_temp': '-76.0',
#   'month': '1',
#   'pressure': '872.0',
#   'sol': '382',
#   'terrestrial_date': '2013-09-02'},
#  {'id': '342',
#   'ls': '16',
#   'min_temp': '-77.0',
#   'month': '1',
#   'pressure': '874.0',
#   'sol': '383',
#   'terrestrial_date': '2013-09-03'},
#  {'id': '346',
#   'ls': '16',
#   'min_temp': '-77.0',
#   'month': '1',
#   'pressure': '875.0',
#   'sol': '384',
#   'terrestrial_date': '2013-09-04'},
#  {'id': '351',
#   'ls': '17',
#   'min_temp': '-78.0',
#   'month': '1',
#   'pressure': '874.0',
#   'sol': '385',
#   'terrestrial_date': '2013-09-05'},
#  {'id': '347',
#   'ls': '17',
#   'min_temp': '-77.0',
#   'month': '1',
#   'pressure': '873.0',
#   'sol': '386',
# ...
#  {'id': '1787',
#   'ls': '84',
#   'min_temp': '-81.0',
#   'month': '3',
#   'pressure': '846.0',
#   'sol': '1869',
#   'terrestrial_date': '2017-11-08'},
#  {'id': '1788',
#   'ls': '85',
#   'min_temp': '-81.0',
#   'month': '3',
#   'pressure': '845.0',
#   'sol': '1870',
#   'terrestrial_date': '2017-11-09'},
#  {'id': '1789',
#   'ls': '85',
#   'min_temp': '-80.0',
#   'month': '3',
#   'pressure': '844.0',
#   'sol': '1871',
#   'terrestrial_date': '2017-11-10'},
#  {'id': '1791',
#   'ls': '86',
#   'min_temp': '-79.0',
#   'month': '3',
#   'pressure': '843.0',
#   'sol': '1872',
#   'terrestrial_date': '2017-11-11'},
#  {'id': '1790',
#   'ls': '86',
#   'min_temp': '-79.0',
#   'month': '3',
#   'pressure': '842.0',
#   'sol': '1873',
#   'terrestrial_date': '2017-11-12'},
#  {'id': '1792',
#   'ls': '86',
#   'min_temp': '-80.0',
#   'month': '3',
#   'pressure': '840.0',
#   'sol': '1874',
#   'terrestrial_date': '2017-11-13'},
#  {'id': '1793',
#   'ls': '87',
#   'min_temp': '-79.0',
#   'month': '3',
#   'pressure': '839.0',
#   'sol': '1875',
#   'terrestrial_date': '2017-11-14'},
#  {'id': '1794',
#   'ls': '87',
#   'min_temp': '-79.0',
#   'month': '3',
#   'pressure': '838.0',
#   'sol': '1876',
#   'terrestrial_date': '2017-11-15'},
#  {'id': '1797',
#   'ls': '88',
#   'min_temp': '-79.0',
#   'month': '3',
#   'pressure': '837.0',
#   'sol': '1877',
#   'terrestrial_date': '2017-11-16'},
#  {'id': '1795',
#   'ls': '88',
#   'min_temp': '-79.0',
#   'month': '3',
#   'pressure': '835.0',
#   'sol': '1878',
#   'terrestrial_date': '2017-11-17'},
#  {'id': '1796',
#   'ls': '89',
#   'min_temp': '-79.0',
#   'month': '3',
#   'pressure': '834.0',
#   'sol': '1879',
#   'terrestrial_date': '2017-11-18'},
#  {'id': '1798',
#   'ls': '89',
#   'min_temp': '-79.0',
#   'month': '3',
#   'pressure': '833.0',
#   'sol': '1880',
#   'terrestrial_date': '2017-11-19'},
#  {'id': '1803',
#   'ls': '90',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '832.0',
#   'sol': '1881',
#   'terrestrial_date': '2017-11-20'},
#  {'id': '1801',
#   'ls': '90',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '831.0',
#   'sol': '1882',
#   'terrestrial_date': '2017-11-21'},
#  {'id': '1800',
#   'ls': '91',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '830.0',
#   'sol': '1883',
#   'terrestrial_date': '2017-11-22'},
#  {'id': '1799',
#   'ls': '91',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '829.0',
#   'sol': '1884',
#   'terrestrial_date': '2017-11-23'},
#  {'id': '1804',
#   'ls': '91',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '827.0',
#   'sol': '1885',
#   'terrestrial_date': '2017-11-24'},
#  {'id': '1805',
#   'ls': '92',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '826.0',
#   'sol': '1886',
#   'terrestrial_date': '2017-11-25'},
#  {'id': '1802',
#   'ls': '92',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '824.0',
#   'sol': '1887',
#   'terrestrial_date': '2017-11-26'},
#  {'id': '1807',
#   'ls': '93',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '823.0',
#   'sol': '1888',
#   'terrestrial_date': '2017-11-27'},
#  {'id': '1806',
#   'ls': '93',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '822.0',
#   'sol': '1889',
#   'terrestrial_date': '2017-11-29'},
#  {'id': '1808',
#   'ls': '94',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '821.0',
#   'sol': '1890',
#   'terrestrial_date': '2017-11-30'},
#  {'id': '1810',
#   'ls': '94',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '819.0',
#   'sol': '1891',
#   'terrestrial_date': '2017-12-01'},
#  {'id': '1809',
#   'ls': '95',
#   'min_temp': '-81.0',
#   'month': '4',
#   'pressure': '817.0',
#   'sol': '1892',
#   'terrestrial_date': '2017-12-02'},
#  {'id': '1812',
#   'ls': '95',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '816.0',
#   'sol': '1893',
#   'terrestrial_date': '2017-12-03'},
#  {'id': '1811',
#   'ls': '96',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '815.0',
#   'sol': '1894',
#   'terrestrial_date': '2017-12-04'},
#  {'id': '1814',
#   'ls': '96',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '814.0',
#   'sol': '1895',
#   'terrestrial_date': '2017-12-05'},
#  {'id': '1813',
#   'ls': '96',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '812.0',
#   'sol': '1896',
#   'terrestrial_date': '2017-12-06'},
#  {'id': '1817',
#   'ls': '97',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '811.0',
#   'sol': '1897',
#   'terrestrial_date': '2017-12-07'},
#  {'id': '1816',
#   'ls': '97',
#   'min_temp': '-81.0',
#   'month': '4',
#   'pressure': '810.0',
#   'sol': '1898',
#   'terrestrial_date': '2017-12-08'},
#  {'id': '1815',
#   'ls': '98',
#   'min_temp': '-81.0',
#   'month': '4',
#   'pressure': '808.0',
#   'sol': '1899',
#   'terrestrial_date': '2017-12-09'},
#  {'id': '1818',
#   'ls': '98',
#   'min_temp': '-81.0',
#   'month': '4',
#   'pressure': '807.0',
#   'sol': '1900',
#   'terrestrial_date': '2017-12-10'},
#  {'id': '1819',
#   'ls': '99',
#   'min_temp': '-81.0',
#   'month': '4',
#   'pressure': '806.0',
#   'sol': '1901',
#   'terrestrial_date': '2017-12-11'},
#  {'id': '1820',
#   'ls': '99',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '804.0',
#   'sol': '1902',
#   'terrestrial_date': '2017-12-12'},
#  {'id': '1821',
#   'ls': '100',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '803.0',
#   'sol': '1903',
#   'terrestrial_date': '2017-12-13'},
#  {'id': '1822',
#   'ls': '100',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '801.0',
#   'sol': '1904',
#   'terrestrial_date': '2017-12-14'},
#  {'id': '1823',
#   'ls': '101',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '800.0',
#   'sol': '1905',
#   'terrestrial_date': '2017-12-15'},
#  {'id': '1824',
#   'ls': '101',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '799.0',
#   'sol': '1906',
#   'terrestrial_date': '2017-12-16'},
#  {'id': '1825',
#   'ls': '101',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '798.0',
#   'sol': '1907',
#   'terrestrial_date': '2017-12-17'},
#  {'id': '1826',
#   'ls': '102',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '796.0',
#   'sol': '1908',
#   'terrestrial_date': '2017-12-18'},
#  {'id': '1827',
#   'ls': '102',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '795.0',
#   'sol': '1909',
#   'terrestrial_date': '2017-12-19'},
#  {'id': '1828',
#   'ls': '103',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '794.0',
#   'sol': '1910',
#   'terrestrial_date': '2017-12-20'},
#  {'id': '1833',
#   'ls': '103',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '792.0',
#   'sol': '1911',
#   'terrestrial_date': '2017-12-21'},
#  {'id': '1832',
#   'ls': '104',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '791.0',
#   'sol': '1912',
#   'terrestrial_date': '2017-12-22'},
#  {'id': '1830',
#   'ls': '104',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '791.0',
#   'sol': '1913',
#   'terrestrial_date': '2017-12-23'},
#  {'id': '1834',
#   'ls': '105',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '790.0',
#   'sol': '1914',
#   'terrestrial_date': '2017-12-24'},
#  {'id': '1835',
#   'ls': '105',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '788.0',
#   'sol': '1915',
#   'terrestrial_date': '2017-12-25'},
#  {'id': '1829',
#   'ls': '106',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '787.0',
#   'sol': '1916',
#   'terrestrial_date': '2017-12-26'},
#  {'id': '1831',
#   'ls': '106',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '786.0',
#   'sol': '1917',
#   'terrestrial_date': '2017-12-27'},
#  {'id': '1839',
#   'ls': '107',
#   'min_temp': '-77.0',
#   'month': '4',
#   'pressure': '784.0',
#   'sol': '1918',
#   'terrestrial_date': '2017-12-28'},
#  {'id': '1836',
#   'ls': '107',
#   'min_temp': '-77.0',
#   'month': '4',
#   'pressure': '783.0',
#   'sol': '1919',
#   'terrestrial_date': '2017-12-29'},
#  {'id': '1837',
#   'ls': '108',
#   'min_temp': '-77.0',
#   'month': '4',
#   'pressure': '782.0',
#   'sol': '1920',
#   'terrestrial_date': '2017-12-30'},
#  {'id': '1838',
#   'ls': '108',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '781.0',
#   'sol': '1921',
#   'terrestrial_date': '2017-12-31'},
#  {'id': '1840',
#   'ls': '108',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '780.0',
#   'sol': '1922',
#   'terrestrial_date': '2018-01-01'},
#  {'id': '1842',
#   'ls': '109',
#   'min_temp': '-77.0',
#   'month': '4',
#   'pressure': '778.0',
#   'sol': '1923',
#   'terrestrial_date': '2018-01-02'},
#  {'id': '1841',
#   'ls': '109',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '777.0',
#   'sol': '1924',
#   'terrestrial_date': '2018-01-03'},
#  {'id': '1844',
#   'ls': '110',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '777.0',
#   'sol': '1925',
#   'terrestrial_date': '2018-01-05'},
#  {'id': '1843',
#   'ls': '110',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '775.0',
#   'sol': '1926',
#   'terrestrial_date': '2018-01-06'},
#  {'id': '1845',
#   'ls': '111',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '774.0',
#   'sol': '1927',
#   'terrestrial_date': '2018-01-07'},
#  {'id': '1847',
#   'ls': '111',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '773.0',
#   'sol': '1928',
#   'terrestrial_date': '2018-01-08'},
#  {'id': '1846',
#   'ls': '112',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '771.0',
#   'sol': '1929',
#   'terrestrial_date': '2018-01-09'},
#  {'id': '1848',
#   'ls': '112',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '770.0',
#   'sol': '1930',
#   'terrestrial_date': '2018-01-10'},
#  {'id': '1849',
#   'ls': '113',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '770.0',
#   'sol': '1931',
#   'terrestrial_date': '2018-01-11'},
#  {'id': '1850',
#   'ls': '113',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '768.0',
#   'sol': '1932',
#   'terrestrial_date': '2018-01-12'},
#  {'id': '1852',
#   'ls': '114',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '767.0',
#   'sol': '1933',
#   'terrestrial_date': '2018-01-13'},
#  {'id': '1851',
#   'ls': '114',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '766.0',
#   'sol': '1934',
#   'terrestrial_date': '2018-01-14'},
#  {'id': '1853',
#   'ls': '115',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '765.0',
#   'sol': '1935',
#   'terrestrial_date': '2018-01-15'},
#  {'id': '1855',
#   'ls': '115',
#   'min_temp': '-79.0',
#   'month': '4',
#   'pressure': '764.0',
#   'sol': '1936',
#   'terrestrial_date': '2018-01-16'},
#  {'id': '1854',
#   'ls': '116',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '763.0',
#   'sol': '1937',
#   'terrestrial_date': '2018-01-17'},
#  {'id': '1859',
#   'ls': '116',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '762.0',
#   'sol': '1938',
#   'terrestrial_date': '2018-01-18'},
#  {'id': '1857',
#   'ls': '116',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '760.0',
#   'sol': '1939',
#   'terrestrial_date': '2018-01-19'},
#  {'id': '1858',
#   'ls': '117',
#   'min_temp': '-77.0',
#   'month': '4',
#   'pressure': '759.0',
#   'sol': '1940',
#   'terrestrial_date': '2018-01-20'},
#  {'id': '1856',
#   'ls': '117',
#   'min_temp': '-77.0',
#   'month': '4',
#   'pressure': '758.0',
#   'sol': '1941',
#   'terrestrial_date': '2018-01-21'},
#  {'id': '1860',
#   'ls': '118',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '757.0',
#   'sol': '1942',
#   'terrestrial_date': '2018-01-22'},
#  {'id': '1863',
#   'ls': '118',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '756.0',
#   'sol': '1943',
#   'terrestrial_date': '2018-01-23'},
#  {'id': '1861',
#   'ls': '119',
#   'min_temp': '-80.0',
#   'month': '4',
#   'pressure': '755.0',
#   'sol': '1944',
#   'terrestrial_date': '2018-01-24'},
#  {'id': '1862',
#   'ls': '119',
#   'min_temp': '-78.0',
#   'month': '4',
#   'pressure': '754.0',
#   'sol': '1945',
#   'terrestrial_date': '2018-01-25'},
#  {'id': '1864',
#   'ls': '120',
#   'min_temp': '-79.0',
#   'month': '5',
#   'pressure': '753.0',
#   'sol': '1946',
#   'terrestrial_date': '2018-01-26'},
#  {'id': '1865',
#   'ls': '120',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '751.0',
#   'sol': '1947',
#   'terrestrial_date': '2018-01-27'},
#  {'id': '1866',
#   'ls': '121',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '752.0',
#   'sol': '1948',
#   'terrestrial_date': '2018-01-28'},
#  {'id': '1867',
#   'ls': '121',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '751.0',
#   'sol': '1949',
#   'terrestrial_date': '2018-01-29'},
#  {'id': '1868',
#   'ls': '122',
#   'min_temp': '-79.0',
#   'month': '5',
#   'pressure': '750.0',
#   'sol': '1950',
#   'terrestrial_date': '2018-01-30'},
#  {'id': '1869',
#   'ls': '122',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '749.0',
#   'sol': '1951',
#   'terrestrial_date': '2018-01-31'},
#  {'id': '1871',
#   'ls': '123',
#   'min_temp': '-80.0',
#   'month': '5',
#   'pressure': '748.0',
#   'sol': '1952',
#   'terrestrial_date': '2018-02-01'},
#  {'id': '1870',
#   'ls': '123',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '747.0',
#   'sol': '1953',
#   'terrestrial_date': '2018-02-02'},
#  {'id': '1872',
#   'ls': '124',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '745.0',
#   'sol': '1954',
#   'terrestrial_date': '2018-02-03'},
#  {'id': '1873',
#   'ls': '124',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '745.0',
#   'sol': '1955',
#   'terrestrial_date': '2018-02-04'},
#  {'id': '1879',
#   'ls': '125',
#   'min_temp': '-79.0',
#   'month': '5',
#   'pressure': '744.0',
#   'sol': '1956',
#   'terrestrial_date': '2018-02-05'},
#  {'id': '1875',
#   'ls': '125',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '742.0',
#   'sol': '1957',
#   'terrestrial_date': '2018-02-06'},
#  {'id': '1874',
#   'ls': '126',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '741.0',
#   'sol': '1958',
#   'terrestrial_date': '2018-02-07'},
#  {'id': '1878',
#   'ls': '126',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '740.0',
#   'sol': '1959',
#   'terrestrial_date': '2018-02-08'},
#  {'id': '1876',
#   'ls': '127',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '740.0',
#   'sol': '1960',
#   'terrestrial_date': '2018-02-09'},
#  {'id': '1877',
#   'ls': '127',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '740.0',
#   'sol': '1961',
#   'terrestrial_date': '2018-02-11'},
#  {'id': '1880',
#   'ls': '128',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '738.0',
#   'sol': '1962',
#   'terrestrial_date': '2018-02-12'},
#  {'id': '1881',
#   'ls': '128',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '737.0',
#   'sol': '1963',
#   'terrestrial_date': '2018-02-13'},
#  {'id': '1882',
#   'ls': '129',
#   'min_temp': '-76.0',
#   'month': '5',
#   'pressure': '736.0',
#   'sol': '1964',
#   'terrestrial_date': '2018-02-14'},
#  {'id': '1883',
#   'ls': '129',
#   'min_temp': '-76.0',
#   'month': '5',
#   'pressure': '735.0',
#   'sol': '1965',
#   'terrestrial_date': '2018-02-15'},
#  {'id': '1884',
#   'ls': '130',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '735.0',
#   'sol': '1966',
#   'terrestrial_date': '2018-02-16'},
#  {'id': '1885',
#   'ls': '130',
#   'min_temp': '-76.0',
#   'month': '5',
#   'pressure': '734.0',
#   'sol': '1967',
#   'terrestrial_date': '2018-02-17'},
#  {'id': '1886',
#   'ls': '131',
#   'min_temp': '-76.0',
#   'month': '5',
#   'pressure': '732.0',
#   'sol': '1968',
#   'terrestrial_date': '2018-02-18'},
#  {'id': '1887',
#   'ls': '131',
#   'min_temp': '-76.0',
#   'month': '5',
#   'pressure': '732.0',
#   'sol': '1969',
#   'terrestrial_date': '2018-02-19'},
#  {'id': '1888',
#   'ls': '132',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '731.0',
#   'sol': '1970',
#   'terrestrial_date': '2018-02-20'},
#  {'id': '1890',
#   'ls': '132',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '731.0',
#   'sol': '1971',
#   'terrestrial_date': '2018-02-21'},
#  {'id': '1891',
#   'ls': '133',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '730.0',
#   'sol': '1972',
#   'terrestrial_date': '2018-02-22'},
#  {'id': '1889',
#   'ls': '133',
#   'min_temp': '-78.0',
#   'month': '5',
#   'pressure': '730.0',
#   'sol': '1973',
#   'terrestrial_date': '2018-02-23'},
#  {'id': '1892',
#   'ls': '134',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '729.0',
#   'sol': '1974',
#   'terrestrial_date': '2018-02-24'},
#  {'id': '1894',
#   'ls': '134',
#   'min_temp': '-76.0',
#   'month': '5',
#   'pressure': '729.0',
#   'sol': '1975',
#   'terrestrial_date': '2018-02-25'},
#  {'id': '1893',
#   'ls': '135',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '728.0',
#   'sol': '1976',
#   'terrestrial_date': '2018-02-26'},
#  {'id': '1895',
#   'ls': '135',
#   'min_temp': '-77.0',
#   'month': '5',
#   'pressure': '727.0',
#   'sol': '1977',
#   'terrestrial_date': '2018-02-27'}]

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
mars_df = pd.DataFrame(mars_data)

# %%
# Confirm DataFrame was created successfully
mars_df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
# mars_df.info()
mars_df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
mars_df['terrestrial_date'] = pd.to_datetime(mars_df['terrestrial_date'])
mars_df['sol'] = mars_df['sol'].astype(int)
mars_df['ls'] = mars_df['ls'].astype(int)
mars_df['month'] = mars_df['month'].astype(int)
mars_df['min_temp'] = mars_df['min_temp'].astype(float)
mars_df['pressure'] = mars_df['pressure'].astype(float)

# %%
# Confirm type changes were successful by examining data types again
mars_df.dtypes
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int64
# ls                           int64
# month                        int64
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
mars_df["month"].value_counts().sort_index()
# Out:
# month
# 1     174
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# 10    112
# 11    138
# 12    166
# Name: count, dtype: int64

# %%
# 2. How many Martian days' worth of data are there?
len(mars_df)
# Out:
# 1867

# %%
# 3. What is the average low temperature by month?
avg_monthly_temp = mars_df.groupby('month')['min_temp'].mean()
avg_monthly_temp
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average temperature by month
avg_monthly_temp.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Temperature in Celsius')
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location
sorted_avg_temp = avg_monthly_temp.sort_values()

sorted_avg_temp.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Temperature in Celsius')
plt.show()

# %%
# 4. Average pressure by Martian month
avg_pressure = mars_df.groupby('month')['pressure'].mean()
avg_pressure
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
sorted_avg_pressure = avg_pressure.sort_values()

sorted_avg_pressure.plot(kind = 'bar')
plt.xlabel('month')
plt.ylabel ('Atmospheric Pressure')
plt.show()

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
mars_df['min_temp'].plot()
plt.xlabel('Number of terrestrial days')
plt.ylabel('Minimum Temperature')
plt.show()

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
mars_df.to_csv("Mars_Temperature_Data.csv", encoding="utf-8", index=False , header=True)

# %%
browser.quit()
